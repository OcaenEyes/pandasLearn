# %%
import pandas as pd
import numpy as np
import warnings

# %% [markdown]
# ## 数据读取

# %%
path = '../dataset/excel_pandas/示例数据.xlsx'

# %%
df = pd.read_excel(path)
df.head()
# Out:
#                  创建时间  地址    岗位  学历                      技能要求   工作经验     薪资水平
# 0 2020-03-16 12:28:11  广州  数据开发  本科  ['Hive', '数据挖掘', '数据分析']   3-5年  20000.0
# 1 2020-03-16 12:39:03  广州  数据分析  本科           ['数据分析', '数据库']   1-3年  13000.0
# 2 2020-03-16 12:01:37  广州  数据分析  本科            ['数据分析', '商业']  应届毕业生   8000.0
# 3 2020-03-16 11:19:51  广州  数据分析  本科    ['SQL', '数据分析', '数据库']   3-5年  20000.0
# 4 2020-03-16 11:18:49  广州  数据分析  大专                  ['数据分析']   1-3年   8000.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 825 entries, 0 to 824
# Data columns (total 7 columns):
# 创建时间    825 non-null datetime64[ns]
# 地址      825 non-null object
# 岗位      825 non-null object
# 学历      825 non-null object
# 技能要求    825 non-null object
# 工作经验    825 non-null object
# 薪资水平    823 non-null float64
# dtypes: datetime64[ns](1), float64(1), object(5)
# memory usage: 45.2+ KB

# %%
df['薪资水平'].describe()
# Out:
# count      823.000000
# mean     18845.078979
# std       9631.848375
# min       1000.000000
# 25%      12000.000000
# 50%      17500.000000
# 75%      25000.000000
# max      60000.000000
# Name: 薪资水平, dtype: float64

# %% [markdown]
# ## 数据生成

# %%
data = pd.DataFrame(np.random.rand(10,2))
data
# Out:
#           0         1
# 0  0.138396  0.669762
# 1  0.163816  0.298192
# 2  0.929119  0.459105
# 3  0.697484  0.973870
# 4  0.103413  0.494012
# 5  0.931636  0.403044
# 6  0.808928  0.671348
# 7  0.623737  0.823124
# 8  0.336116  0.843412
# 9  0.995926  0.980337

# %% [markdown]
# ## 数据保存

# %%
data.to_excel("测试练习数据.xlsx")

# %% [markdown]
# ## 数据筛选

# %%
df[df['薪资水平']>5000]
# Out:
#                    创建时间  地址      岗位  学历  \
# 0   2020-03-16 12:28:11  广州    数据开发  本科
# 1   2020-03-16 12:39:03  广州    数据分析  本科
# 2   2020-03-16 12:01:37  广州    数据分析  本科
# 3   2020-03-16 11:19:51  广州    数据分析  本科
# 4   2020-03-16 11:18:49  广州    数据分析  大专
# 5   2020-03-16 11:34:57  广州    数据开发  本科
# 6   2020-03-16 11:36:54  广州    数据开发  大专
# 7   2020-03-16 11:36:52  广州    数据开发  大专
# 8   2020-03-16 09:33:49  广州    数据开发  本科
# 9   2020-03-16 11:40:29  广州    数据开发  本科
# 10  2020-03-16 12:21:59  广州      运营  本科
# 11  2020-03-16 12:04:22  广州    数据开发  本科
# 12  2020-03-16 12:01:46  广州  高端产品职位  本科
# 13  2020-03-16 12:01:47  广州    数据开发  本科
# 14  2020-03-16 12:01:44  广州    产品经理  本科
# 15  2020-03-16 12:01:47  广州    数据开发  本科
# 16  2020-03-14 16:53:16  广州      运营  大专
# 17  2020-03-16 11:09:31  广州    数据分析  本科
# 18  2020-03-16 10:44:41  广州    数据开发  本科
# 19  2020-03-16 12:04:23  广州    数据分析  本科
# 21  2020-03-16 12:01:46  广州  高端产品职位  本科
# 22  2020-03-16 10:06:16  广州    数据开发  本科
# ...

# %% [markdown]
# ## 数据插入

# %%
bins = [0,10000,max(df["薪资水平"])]
group_names=['低','高']
df['new_col'] = pd.cut(df['薪资水平'], bins, labels=group_names)

# %%
df.head(10)
# Out:
#                  创建时间  地址    岗位  学历                                 技能要求  \
# 0 2020-03-16 12:28:11  广州  数据开发  本科             ['Hive', '数据挖掘', '数据分析']
# 1 2020-03-16 12:39:03  广州  数据分析  本科                      ['数据分析', '数据库']
# 2 2020-03-16 12:01:37  广州  数据分析  本科                       ['数据分析', '商业']
# 3 2020-03-16 11:19:51  广州  数据分析  本科               ['SQL', '数据分析', '数据库']
# 4 2020-03-16 11:18:49  广州  数据分析  大专                             ['数据分析']
# 5 2020-03-16 11:34:57  广州  数据开发  本科  ['Spark', 'Hadoop', '数据处理', '数据分析']
# 6 2020-03-16 11:36:54  广州  数据开发  大专                             ['数据分析']
# 7 2020-03-16 11:36:52  广州  数据开发  大专                             ['数据分析']
# 8 2020-03-16 09:33:49  广州  数据开发  本科             ['数据架构', '数据分析', '数据处理']
# 9 2020-03-16 11:40:29  广州  数据开发  本科                             ['数据分析']
#
#     工作经验     薪资水平 new_col
# 0   3-5年  20000.0       高
# 1   1-3年  13000.0       高
# 2  应届毕业生   8000.0       低
# 3   3-5年  20000.0       高
# 4   1-3年   8000.0       低
# ...

# %% [markdown]
# ## 数据删除

# %%
del df['new_col']
df.head(10)
# Out:
#                  创建时间  地址    岗位  学历                                 技能要求  \
# 0 2020-03-16 12:28:11  广州  数据开发  本科             ['Hive', '数据挖掘', '数据分析']
# 1 2020-03-16 12:39:03  广州  数据分析  本科                      ['数据分析', '数据库']
# 2 2020-03-16 12:01:37  广州  数据分析  本科                       ['数据分析', '商业']
# 3 2020-03-16 11:19:51  广州  数据分析  本科               ['SQL', '数据分析', '数据库']
# 4 2020-03-16 11:18:49  广州  数据分析  大专                             ['数据分析']
# 5 2020-03-16 11:34:57  广州  数据开发  本科  ['Spark', 'Hadoop', '数据处理', '数据分析']
# 6 2020-03-16 11:36:54  广州  数据开发  大专                             ['数据分析']
# 7 2020-03-16 11:36:52  广州  数据开发  大专                             ['数据分析']
# 8 2020-03-16 09:33:49  广州  数据开发  本科             ['数据架构', '数据分析', '数据处理']
# 9 2020-03-16 11:40:29  广州  数据开发  本科                             ['数据分析']
#
#     工作经验     薪资水平
# 0   3-5年  20000.0
# 1   1-3年  13000.0
# 2  应届毕业生   8000.0
# 3   3-5年  20000.0
# 4   1-3年   8000.0
# 5  5-10年  23000.0
# 6   1-3年   8500.0
# ...

# %% [markdown]
# ## 数据排序

# %%
df1 =df
df1.sort_values('薪资水平')
# Out:
#                    创建时间  地址      岗位  学历  \
# 742 2020-03-16 00:00:14  深圳    数据分析  本科
# 132 2020-03-12 16:41:04  广州   市场|营销  本科
# 593 2020-03-16 11:03:01  深圳    数据分析  本科
# 738 2020-03-15 15:10:49  深圳    数据开发  不限
# 611 2020-03-15 15:10:49  深圳    数据开发  本科
# 644 2020-03-16 11:03:01  深圳    数据分析  本科
# 599 2020-03-16 11:01:44  深圳    数据分析  本科
# 109 2020-03-16 10:23:15  广州    数据分析  硕士
# 419 2020-03-16 12:04:12  北京    数据分析  本科
# 155 2020-03-12 10:20:35  广州    数据开发  本科
# 645 2020-03-16 11:02:51  深圳    数据开发  本科
# 316 2020-03-16 12:24:31  北京    数据分析  本科
# 20  2020-03-16 12:04:22  广州    数据开发  不限
# 366 2020-03-16 12:24:31  北京    数据分析  本科
# 824 2020-03-16 10:37:24  深圳    数据分析  本科
# 137 2020-03-14 16:56:49  广州    数据分析  本科
# 133 2020-03-14 16:48:20  广州    数据开发  本科
# 417 2020-03-16 09:51:36  北京    数据开发  本科
# 229 2020-03-16 10:47:15  杭州    数据开发  本科
# 714 2020-03-16 10:08:48  深圳   市场|营销  本科
# 720 2020-03-16 10:41:45  深圳    数据开发  本科
# 134 2020-01-02 14:05:26  广州    数据分析  本科
# ...

# %%
df1.sort_values('薪资水平',ascending=False)
# Out:
#                    创建时间  地址      岗位  学历  \
# 789 2020-03-13 00:45:34  深圳    数据开发  本科
# 694 2020-03-16 11:19:31  深圳    数据分析  本科
# 744 2020-03-03 22:12:28  深圳    数据开发  本科
# 750 2020-03-03 22:12:28  深圳    数据开发  本科
# 759 2020-03-03 19:55:13  深圳    人工智能  本科
# 432 2020-03-16 12:36:22  北京    数据开发  本科
# 241 2020-03-16 10:08:53  杭州    后端开发  本科
# 255 2020-03-15 14:22:49  杭州    数据开发  本科
# 301 2020-03-16 12:01:46  北京    数据开发  本科
# 341 2020-03-16 10:05:51  北京    数据开发  本科
# 299 2020-03-16 12:01:02  北京    数据分析  本科
# 488 2020-03-16 11:30:17  上海    数据开发  本科
# 582 2020-03-16 08:55:54  深圳    数据开发  硕士
# 743 2020-03-16 00:00:28  深圳    数据开发  本科
# 182 2020-03-16 11:08:54  杭州    数据开发  本科
# 643 2020-03-16 11:03:40  深圳    数据开发  本科
# 815 2020-03-16 11:00:56  深圳    数据分析  本科
# 808 2020-03-16 11:03:42  深圳   互联网金融  本科
# 472 2020-03-16 11:04:00  上海  高端技术职位  本科
# 374 2020-03-16 12:05:49  北京    数据分析  本科
# 286 2020-03-16 09:16:57  北京    数据分析  本科
# 192 2020-03-16 11:24:46  杭州    数据分析  本科
# ...

# %% [markdown]
# ## 缺失值处理

# %%
df.isnull().sum()
# Out:
# 创建时间    0
# 地址      0
# 岗位      0
# 学历      0
# 技能要求    0
# 工作经验    0
# 薪资水平    2
# dtype: int64

# %%
df2 = df
df2 = df2.fillna(axis=0,method='ffill')
df2.isnull().sum()
# Out:
# 创建时间    0
# 地址      0
# 岗位      0
# 学历      0
# 技能要求    0
# 工作经验    0
# 薪资水平    0
# dtype: int64

# %%
df2[df2.index == 26]
# Out:
#                   创建时间  地址    岗位  学历      技能要求   工作经验     薪资水平
# 26 2020-03-16 12:00:20  广州  数据开发  本科  ['数据分析']  5-10年  13500.0

# %% [markdown]
# ## 数据去重

# %%
df3 =df
df3.drop_duplicates(['创建时间'],inplace=True)
df3
# Out:
#                    创建时间  地址      岗位  学历  \
# 0   2020-03-16 12:28:11  广州    数据开发  本科
# 1   2020-03-16 12:39:03  广州    数据分析  本科
# 2   2020-03-16 12:01:37  广州    数据分析  本科
# 3   2020-03-16 11:19:51  广州    数据分析  本科
# 4   2020-03-16 11:18:49  广州    数据分析  大专
# 5   2020-03-16 11:34:57  广州    数据开发  本科
# 6   2020-03-16 11:36:54  广州    数据开发  大专
# 7   2020-03-16 11:36:52  广州    数据开发  大专
# 8   2020-03-16 09:33:49  广州    数据开发  本科
# 9   2020-03-16 11:40:29  广州    数据开发  本科
# 10  2020-03-16 12:21:59  广州      运营  本科
# 11  2020-03-16 12:04:22  广州    数据开发  本科
# 12  2020-03-16 12:01:46  广州  高端产品职位  本科
# 13  2020-03-16 12:01:47  广州    数据开发  本科
# 14  2020-03-16 12:01:44  广州    产品经理  本科
# 16  2020-03-14 16:53:16  广州      运营  大专
# 17  2020-03-16 11:09:31  广州    数据分析  本科
# 18  2020-03-16 10:44:41  广州    数据开发  本科
# 19  2020-03-16 12:04:23  广州    数据分析  本科
# 22  2020-03-16 10:06:16  广州    数据开发  本科
# 23  2020-03-16 12:01:49  广州    产品经理  本科
# 24  2020-03-16 12:02:02  广州    数据开发  本科
# ...

# %% [markdown]
# ## 格式修改

# %%
df4 = df
df4['创建时间'] = df4['创建时间'].dt.strftime('%Y-%m-%d')
df4
# Out:
#            创建时间  地址      岗位  学历                                    技能要求  \
# 0    2020-03-16  广州    数据开发  本科                ['Hive', '数据挖掘', '数据分析']
# 1    2020-03-16  广州    数据分析  本科                         ['数据分析', '数据库']
# 2    2020-03-16  广州    数据分析  本科                          ['数据分析', '商业']
# 3    2020-03-16  广州    数据分析  本科                  ['SQL', '数据分析', '数据库']
# 4    2020-03-16  广州    数据分析  大专                                ['数据分析']
# 5    2020-03-16  广州    数据开发  本科     ['Spark', 'Hadoop', '数据处理', '数据分析']
# 6    2020-03-16  广州    数据开发  大专                                ['数据分析']
# 7    2020-03-16  广州    数据开发  大专                                ['数据分析']
# 8    2020-03-16  广州    数据开发  本科                ['数据架构', '数据分析', '数据处理']
# 9    2020-03-16  广州    数据开发  本科                                ['数据分析']
# 10   2020-03-16  广州      运营  本科                          ['运营', '策略运营']
# 11   2020-03-16  广州    数据开发  本科                        ['Hive', '数据分析']
# ...

# %% [markdown]
# ## 数据交换

# %%
cols = df.columns[[0,2,1,3,4,5,6]]
df5 = df[cols]
df5
# Out:
#            创建时间      岗位  地址  学历                                    技能要求  \
# 0    2020-03-16    数据开发  广州  本科                ['Hive', '数据挖掘', '数据分析']
# 1    2020-03-16    数据分析  广州  本科                         ['数据分析', '数据库']
# 2    2020-03-16    数据分析  广州  本科                          ['数据分析', '商业']
# 3    2020-03-16    数据分析  广州  本科                  ['SQL', '数据分析', '数据库']
# 4    2020-03-16    数据分析  广州  大专                                ['数据分析']
# 5    2020-03-16    数据开发  广州  本科     ['Spark', 'Hadoop', '数据处理', '数据分析']
# 6    2020-03-16    数据开发  广州  大专                                ['数据分析']
# 7    2020-03-16    数据开发  广州  大专                                ['数据分析']
# 8    2020-03-16    数据开发  广州  本科                ['数据架构', '数据分析', '数据处理']
# 9    2020-03-16    数据开发  广州  本科                                ['数据分析']
# 10   2020-03-16      运营  广州  本科                          ['运营', '策略运营']
# 11   2020-03-16    数据开发  广州  本科                        ['Hive', '数据分析']
# ...

# %% [markdown]
# ## 数据合并

# %%
df['合并列'] = df['地址']+df['岗位']
df.head(10)
# Out:
#          创建时间  地址    岗位  学历                                 技能要求   工作经验  \
# 0  2020-03-16  广州  数据开发  本科             ['Hive', '数据挖掘', '数据分析']   3-5年
# 1  2020-03-16  广州  数据分析  本科                      ['数据分析', '数据库']   1-3年
# 2  2020-03-16  广州  数据分析  本科                       ['数据分析', '商业']  应届毕业生
# 3  2020-03-16  广州  数据分析  本科               ['SQL', '数据分析', '数据库']   3-5年
# 4  2020-03-16  广州  数据分析  大专                             ['数据分析']   1-3年
# 5  2020-03-16  广州  数据开发  本科  ['Spark', 'Hadoop', '数据处理', '数据分析']  5-10年
# 6  2020-03-16  广州  数据开发  大专                             ['数据分析']   1-3年
# 7  2020-03-16  广州  数据开发  大专                             ['数据分析']   1-3年
# 8  2020-03-16  广州  数据开发  本科             ['数据架构', '数据分析', '数据处理']   1-3年
# 9  2020-03-16  广州  数据开发  本科                             ['数据分析']     不限
#
#       薪资水平     合并列
# 0  20000.0  广州数据开发
# 1  13000.0  广州数据分析
# 2   8000.0  广州数据分析
# 3  20000.0  广州数据分析
# 4   8000.0  广州数据分析
# 5  23000.0  广州数据开发
# 6   8500.0  广州数据开发
# ...

# %% [markdown]
# ## 数据拆分

# %%
df['技能要求'].str.split(',',expand=True)
# Out:
#                 0            1          2           3
# 0         ['Hive'       '数据挖掘'    '数据分析']        None
# 1         ['数据分析'       '数据库']       None        None
# 2         ['数据分析'        '商业']       None        None
# 3          ['SQL'       '数据分析'     '数据库']        None
# 4        ['数据分析']         None       None        None
# 5        ['Spark'     'Hadoop'     '数据处理'     '数据分析']
# 6        ['数据分析']         None       None        None
# 7        ['数据分析']         None       None        None
# 8         ['数据架构'       '数据分析'    '数据处理']        None
# 9        ['数据分析']         None       None        None
# 10          ['运营'      '策略运营']       None        None
# 11        ['Hive'      '数据分析']       None        None
# 12       ['部门管理']         None       None        None
# 13       ['数据分析']         None       None        None
# 14       ['数据分析']         None       None        None
# 16        ['数据分析'      '游戏运营']       None        None
# ...

# %% [markdown]
# ## 数据分组

# %%
df.groupby("学历").mean()
# Out:
#             薪资水平
# 学历
# 不限  18647.058824
# 大专  11775.000000
# 本科  19537.950664
# 硕士  20134.615385

# %% [markdown]
# ## 数据计算

# %%
len(df[df["薪资水平"]>10000])
# Out:
# 518

# %% [markdown]
# ## 数据可视化

# %%
df["薪资水平"].describe()
# Out:
# count      627.000000
# mean     19019.138756
# std       9696.823558
# min       1000.000000
# 25%      12500.000000
# 50%      17500.000000
# 75%      25000.000000
# max      60000.000000
# Name: 薪资水平, dtype: float64

# %% [markdown]
# ## 数据可视化

# %%
df["薪资水平"].hist()

# %% [markdown]
# ## 数据抽样

# %%
df.sample(20)
# Out:
#            创建时间  地址     岗位  学历                                 技能要求   工作经验  \
# 478  2020-03-16  上海   数据分析  本科                               ['BI']   3-5年
# 807  2020-03-16  深圳   数据开发  硕士                             ['数据分析']   3-5年
# 518  2020-03-16  上海   数据开发  本科                     ['数据分析', '数据挖掘']  5-10年
# 493  2020-03-16  上海   数据分析  本科                                   []   1-3年
# 605  2020-03-16  深圳     运营  本科                       ['数据分析', '商务']   3-5年
# 36   2020-03-16  广州   数据分析  本科                             ['数据分析']  应届毕业生
# 513  2020-03-16  上海   数据开发  本科   ['数据分析', 'Hadoop', '数据处理', '数据挖掘']   1-3年
# 434  2020-03-16  北京   数据分析  本科                             ['数据分析']  5-10年
# 590  2020-03-16  深圳   数据分析  本科                      ['数据分析', 'SQL']   3-5年
# 514  2020-03-16  上海   数据分析  本科       ['数据分析', '商业', '增长黑客', '数据运营']  5-10年
# 303  2020-03-16  北京   数据分析  本科                      ['数据分析', 'SQL']   3-5年
# ...

# %% [markdown]
# ## 数据透视表

# %%
pd.pivot_table(df,index=['地址','学历'],values=["薪资水平"])
# Out:
#                薪资水平
# 地址 学历
# 上海 不限  17000.000000
#    大专  10000.000000
#    本科  19464.285714
#    硕士  20642.857143
# 北京 不限  22833.333333
#    大专  19000.000000
#    本科  23726.086957
#    硕士  27500.000000
# 广州 不限  17750.000000
#    大专  10700.000000
#    本科  14916.666667
#    硕士   7666.666667
# 杭州 不限  17733.333333
#    大专  16625.000000
#    本科  20753.623188
#    硕士  14000.000000
# 深圳 不限  18833.333333
#    大专  10437.500000
#    本科  19313.793103
#    硕士  23150.000000

# %% [markdown]
# ## vlookup

# %%
df6 = pd.read_excel("../dataset/excel_pandas/vlookup.xlsx")

# %%
df6.head(10)
# Out:
#   序号  科目   成绩  排名  Unnamed: 4 序号.1  科目.1  成绩.1  排名.1
# 0  A  语文   80   8         NaN    C   NaN   NaN   NaN
# 1  B  数学   70   2         NaN  NaN   NaN   NaN   NaN
# 2  C  英语   60   4         NaN  NaN   NaN   NaN   NaN
# 3  D  政治   50   5         NaN  NaN   NaN   NaN   NaN
# 4  E  地理   90   6         NaN  NaN   NaN   NaN   NaN
# 5  F  化学  100   1         NaN  NaN   NaN   NaN   NaN
# 6  G  生物   77   3         NaN  NaN   NaN   NaN   NaN

# %%
df7 = df6[['序号','科目','成绩','排名']]
df7
# Out:
#   序号  科目   成绩  排名
# 0  A  语文   80   8
# 1  B  数学   70   2
# 2  C  英语   60   4
# 3  D  政治   50   5
# 4  E  地理   90   6
# 5  F  化学  100   1
# 6  G  生物   77   3

# %%
df8 = df6[['序号.1','科目.1','成绩.1','排名.1']]
df8.columns = ['序号','科目','成绩','排名']
df8 = df8.loc[:0]
df8
# Out:
#   序号  科目  成绩  排名
# 0  C NaN NaN NaN

# %%
df7 = df7.set_index("序号")
df7
# Out:
#     科目   成绩  排名
# 序号
# A   语文   80   8
# B   数学   70   2
# C   英语   60   4
# D   政治   50   5
# E   地理   90   6
# F   化学  100   1
# G   生物   77   3

# %%
df8 = df8.set_index("序号")
df8
# Out:
#     科目  成绩  排名
# 序号
# C  NaN NaN NaN

# %%
df8.update(df7)
df8
# Out:
#     科目    成绩   排名
# 序号
# C   英语  60.0  4.0
