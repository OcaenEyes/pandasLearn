# %% [markdown]
# ## 数据采集

# %%
import requests
import pandas as pd
from lxml import etree
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\requests\__init__.py:91: RequestsDependencyWarning: urllib3 (1.25.9) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
html = 'https://3g.dxy.cn/newh5/view/pneumonia'
html_data = requests.get(html)
html_data.encoding = 'utf-8'
html_data = etree.HTML(html_data.text,etree.HTMLParser())
html_data = html_data.xpath(
    '//*[@id="getListByCountryTypeService2true"]/text()'
)

# 集合
ncov_world = html_data[0][49:-12]
ncov_world = ncov_world.replace('true','True')
ncov_world = ncov_world.replace('false','False')
ncov_world = eval(ncov_world)
ncov_world
# Out:
# ({'id': 5840968,
#   'createTime': 1602993273000,
#   'modifyTime': 1602993273000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '北美洲',
#   'provinceId': '8',
#   'provinceName': '美国',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 4662284,
#   'confirmedCount': 8102142,
#   'confirmedCountRank': 1,
#   'suspectedCount': 0,
#   'curedCount': 3220573,
#   'deadCount': 219285,
#   'deadCountRank': 1,
#   'deadRate': '2.70',
#   'deadRateRank': 57,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 971002,
#   'countryShortCode': 'USA',
#   'countryFullName': 'United States of America',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/553/3402160512808052518-135.json',
#   'incrVo': {'currentConfirmedIncr': 73,
#    'confirmedIncr': 202,
#    'curedIncr': 0,
#    'deadIncr': 129},
#   'showRank': True},
#  {'id': 5840979,
#   'createTime': 1602993273000,
#   'modifyTime': 1602993273000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '亚洲',
#   'provinceId': '10',
#   'provinceName': '印度',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 795087,
#   'confirmedCount': 7432680,
#   'confirmedCountRank': 2,
#   'suspectedCount': 0,
#   'curedCount': 6524595,
#   'deadCount': 112998,
#   'deadCountRank': 3,
#   'deadRate': '1.52',
#   'deadRateRank': 124,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 953003,
#   'countryShortCode': 'IND',
#   'countryFullName': 'India',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/045/3402160534282889835-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5840982,
#   'createTime': 1602993273000,
#   'modifyTime': 1602993273000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '欧洲',
#   'provinceId': '10',
#   'provinceName': '西班牙',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 752409,
#   'confirmedCount': 936560,
#   'confirmedCountRank': 7,
#   'suspectedCount': 0,
#   'curedCount': 150376,
#   'deadCount': 33775,
#   'deadCountRank': 7,
#   'deadRate': '3.60',
#   'deadRateRank': 30,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 965015,
#   'countryShortCode': 'ESP',
#   'countryFullName': 'Spain',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/812/3402160512807875660-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5840965,
#   'createTime': 1602993273000,
#   'modifyTime': 1602993273000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '欧洲',
#   'provinceId': '5',
#   'provinceName': '法国',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 696771,
#   'confirmedCount': 834770,
#   'confirmedCountRank': 10,
#   'suspectedCount': 0,
#   'curedCount': 104696,
#   'deadCount': 33303,
#   'deadCountRank': 9,
#   'deadRate': '3.98',
#   'deadRateRank': 24,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 961002,
#   'countryShortCode': 'FRA',
#   'countryFullName': 'France',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/929/3402160538577857318-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5841074,
#   'createTime': 1602993273000,
#   'modifyTime': 1602993273000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '欧洲',
#   'provinceId': '10',
#   'provinceName': '英国',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 661310,
#   'confirmedCount': 705428,
#   'confirmedCountRank': 11,
#   'suspectedCount': 0,
#   'curedCount': 539,
#   'deadCount': 43579,
#   'deadCountRank': 5,
#   'deadRate': '6.17',
#   'deadRateRank': 8,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 961007,
#   'countryShortCode': 'GBR',
#   'countryFullName': 'The United Kingdom',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/364/3402160538577680395-135.json',
#   'incrVo': {'currentConfirmedIncr': 16017,
#    'confirmedIncr': 16167,
#    'curedIncr': 0,
#    'deadIncr': 150},
#   'showRank': True},
#  {'id': 5841024,
#   'createTime': 1602993273000,
#   'modifyTime': 1602993273000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '南美洲',
#   'provinceId': '10',
#   'provinceName': '巴西',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 435357,
#   'confirmedCount': 5224362,
#   'confirmedCountRank': 3,
#   'suspectedCount': 0,
#   'curedCount': 4635315,
#   'deadCount': 153690,
#   'deadCountRank': 2,
#   'deadRate': '2.94',
#   'deadRateRank': 51,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 973003,
#   'countryShortCode': 'BRA',
#   'countryFullName': 'Brazil',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/559/3402160538577857305-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5840981,
#   'createTime': 1602993273000,
#   'modifyTime': 1602993273000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '欧洲',
#   'provinceId': '10',
#   'provinceName': '俄罗斯',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 295034,
#   'confirmedCount': 1384235,
#   'confirmedCountRank': 4,
#   'suspectedCount': 0,
#   'curedCount': 1065199,
#   'deadCount': 24002,
#   'deadCountRank': 13,
#   'deadRate': '1.73',
#   'deadRateRank': 110,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 964006,
#   'countryShortCode': 'RUS',
#   'countryFullName': 'Russian Federation',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/629/3402160517102843039-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5841030,
#   'createTime': 1602993273000,
#   'modifyTime': 1602993273000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '欧洲',
#   'provinceId': '10',
#   'provinceName': '荷兰',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 193105,
#   'confirmedCount': 211690,
#   'confirmedCountRank': 26,
#   'suspectedCount': 0,
#   'curedCount': 11886,
#   'deadCount': 6699,
#   'deadCountRank': 24,
#   'deadRate': '3.16',
#   'deadRateRank': 42,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 961006,
#   'countryShortCode': 'NLD',
#   'countryFullName': 'Netherlands',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/850/3402160510660568773-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5840995,
#   'createTime': 1602993273000,
#   'modifyTime': 1602993273000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '欧洲',
#   'provinceId': '10',
#   'provinceName': '比利时',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 172460,
#   'confirmedCount': 202058,
#   'confirmedCountRank': 27,
#   'suspectedCount': 0,
#   'curedCount': 19239,
#   'deadCount': 10359,
#   'deadCountRank': 18,
#   'deadRate': '5.12',
#   'deadRateRank': 18,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 961001,
#   'countryShortCode': 'BEL',
#   'countryFullName': 'Belgium',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/838/3402160514955359353-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5841110,
#   'createTime': 1602993273000,
#   'modifyTime': 1602993273000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '欧洲',
#   'provinceId': '10',
#   'provinceName': '乌克兰',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 166205,
#   'confirmedCount': 293641,
#   'confirmedCountRank': 25,
#   'suspectedCount': 0,
#   'curedCount': 121919,
#   'deadCount': 5517,
#   'deadCountRank': 31,
#   'deadRate': '1.87',
#   'deadRateRank': 100,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 964007,
#   'countryShortCode': 'UKR',
#   'countryFullName': 'Ukraine',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/280/3402160525692954803-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5841127,
#   'createTime': 1602993273000,
#   'modifyTime': 1602993273000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '南美洲',
#   'provinceId': '10',
#   'provinceName': '阿根廷',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 161838,
#   'confirmedCount': 979106,
#   'confirmedCountRank': 5,
#   'suspectedCount': 0,
#   'curedCount': 791161,
#   'deadCount': 26107,
#   'deadCountRank': 12,
#   'deadRate': '2.66',
#   'deadRateRank': 62,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 973001,
#   'countryShortCode': 'ARG',
#   'countryFullName': 'Argentina',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/963/3402160508513085001-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5841036,
#   'createTime': 1602993273000,
#   'modifyTime': 1602993273000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '北美洲',
#   'provinceId': '10',
#   'provinceName': '墨西哥',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 143741,
#   'confirmedCount': 841661,
#   'confirmedCountRank': 9,
#   'suspectedCount': 0,
#   'curedCount': 612216,
#   'deadCount': 85704,
#   'deadCountRank': 4,
#   'deadRate': '10.18',
#   'deadRateRank': 2,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 971003,
#   'countryShortCode': 'MEX',
#   'countryFullName': 'Mexico',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/566/3402160534282889843-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5840980,
#   'createTime': 1602993273000,
#   'modifyTime': 1602993273000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '欧洲',
#   'provinceId': '10',
#   'provinceName': '意大利',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 107312,
#   'confirmedCount': 391611,
#   'confirmedCountRank': 16,
#   'suspectedCount': 0,
#   'curedCount': 247872,
#   'deadCount': 36427,
#   'deadCountRank': 6,
#   'deadRate': '9.30',
#   'deadRateRank': 3,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 965008,
#   'countryShortCode': 'ITA',
#   'countryFullName': 'Italy',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/993/3402160517102843054-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5841081,
#   'createTime': 1602993273000,
#   'modifyTime': 1602993273000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '欧洲',
#   'provinceId': '10',
#   'provinceName': '捷克',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 95479,
#   'confirmedCount': 160112,
#   'confirmedCountRank': 31,
#   'suspectedCount': 0,
#   'curedCount': 63350,
#   'deadCount': 1283,
#   'deadCountRank': 51,
#   'deadRate': '0.80',
#   'deadRateRank': 164,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 963002,
#   'countryShortCode': 'CZE',
#   'countryFullName': 'Czechia',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/497/3402160532135229255-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5841462,
#   'createTime': 1602993274000,
#   'modifyTime': 1602993274000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '北美洲',
#   'provinceId': '10',
#   'provinceName': '危地马拉',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 93830,
#   'confirmedCount': 100431,
#   'confirmedCountRank': 45,
#   'suspectedCount': 0,
#   'curedCount': 3123,
#   'deadCount': 3478,
#   'deadCountRank': 34,
#   'deadRate': '3.46',
#   'deadRateRank': 33,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 972004,
#   'countryShortCode': 'GTM',
#   'countryFullName': 'Guatemala',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0317/045/3402535547204640218-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5840983,
#   'createTime': 1602993273000,
#   'modifyTime': 1602993273000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '欧洲',
#   'provinceId': '10',
#   'provinceName': '瑞典',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 92311,
#   'confirmedCount': 103200,
#   'confirmedCountRank': 44,
#   'suspectedCount': 0,
#   'curedCount': 4971,
#   'deadCount': 5918,
#   'deadCountRank': 28,
#   'deadRate': '5.73',
#   'deadRateRank': 13,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 962005,
#   'countryShortCode': 'SWE',
#   'countryFullName': 'Sweden',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/516/3402160512807875646-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5841228,
#   'createTime': 1602993273000,
#   'modifyTime': 1602993273000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '北美洲',
#   'provinceId': '10',
#   'provinceName': '哥斯达黎加',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 90713,
#   'confirmedCount': 93152,
#   'confirmedCountRank': 47,
#   'suspectedCount': 0,
#   'curedCount': 1280,
#   'deadCount': 1159,
#   'deadCountRank': 52,
#   'deadRate': '1.24',
#   'deadRateRank': 144,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 972002,
#   'countryShortCode': 'CRI',
#   'countryFullName': 'Costa Rica',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/133/3402160534282889827-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5841464,
#   'createTime': 1602993274000,
#   'modifyTime': 1602993274000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '南美洲',
#   'provinceId': '10',
#   'provinceName': '委内瑞拉',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 83100,
#   'confirmedCount': 85469,
#   'confirmedCountRank': 53,
#   'suspectedCount': 0,
#   'curedCount': 1649,
#   'deadCount': 720,
#   'deadCountRank': 70,
#   'deadRate': '0.84',
#   'deadRateRank': 161,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 0,
#   'countryShortCode': 'VEN',
#   'countryFullName': 'Venezuela',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/824/3402176468611248153-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5841365,
#   'createTime': 1602993273000,
#   'modifyTime': 1602993273000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '北美洲',
#   'provinceId': '10',
#   'provinceName': '洪都拉斯',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 81770,
#   'confirmedCount': 86089,
#   'confirmedCountRank': 52,
#   'suspectedCount': 0,
#   'curedCount': 1767,
#   'deadCount': 2552,
#   'deadCountRank': 37,
#   'deadRate': '2.96',
#   'deadRateRank': 49,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 972005,
#   'countryShortCode': 'HND',
#   'countryFullName': 'Honduras',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/610/3402160540725341073-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5841283,
#   'createTime': 1602993273000,
#   'modifyTime': 1602993273000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '亚洲',
#   'provinceId': '10',
#   'provinceName': '孟加拉国',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 79351,
#   'confirmedCount': 387295,
#   'confirmedCountRank': 17,
#   'suspectedCount': 0,
#   'curedCount': 302298,
#   'deadCount': 5646,
#   'deadCountRank': 30,
#   'deadRate': '1.45',
#   'deadRateRank': 133,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 953001,
#   'countryShortCode': 'BGD',
#   'countryFullName': 'Bangladesh',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/485/3402160532135406028-135.json',
#   'incrVo': {'currentConfirmedIncr': -374,
#    'confirmedIncr': 1209,
#    'curedIncr': 1560,
#    'deadIncr': 23},
#   'showRank': True},
#  {'id': 5841229,
#   'createTime': 1602993273000,
#   'modifyTime': 1602993273000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '南美洲',
#   'provinceId': '10',
#   'provinceName': '哥伦比亚',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 76101,
#   'confirmedCount': 952371,
#   'confirmedCountRank': 6,
#   'suspectedCount': 0,
#   'curedCount': 847467,
#   'deadCount': 28803,
#   'deadCountRank': 11,
#   'deadRate': '3.02',
#   'deadRateRank': 46,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 973005,
#   'countryShortCode': 'COL',
#   'countryFullName': 'Colombia',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/269/3402160512808052512-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5841010,
#   'createTime': 1602993273000,
#   'modifyTime': 1602993273000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '亚洲',
#   'provinceId': '10',
#   'provinceName': '伊朗',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 72446,
#   'confirmedCount': 526490,
#   'confirmedCountRank': 13,
#   'suspectedCount': 0,
#   'curedCount': 423921,
#   'deadCount': 30123,
#   'deadCountRank': 10,
#   'deadRate': '5.72',
#   'deadRateRank': 14,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 955007,
#   'countryShortCode': 'IRN',
#   'countryFullName': 'Iran (Islamic Republic of)',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/596/3402160510660568739-135.json',
#   'incrVo': {'currentConfirmedIncr': 839,
#    'confirmedIncr': 4103,
#    'curedIncr': 3011,
#    'deadIncr': 253},
#   'showRank': True},
#  {'id': 5841206,
#   'createTime': 1602993273000,
#   'modifyTime': 1602993273000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '欧洲',
#   'provinceId': '10',
#   'provinceName': '波兰',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 68580,
#   'confirmedCount': 157608,
#   'confirmedCountRank': 32,
#   'suspectedCount': 0,
#   'curedCount': 85588,
#   'deadCount': 3440,
#   'deadCountRank': 35,
#   'deadRate': '2.18',
#   'deadRateRank': 79,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 963006,
#   'countryShortCode': 'POL',
#   'countryFullName': 'Poland',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/811/3402160506365424422-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5841460,
#   'createTime': 1602993274000,
#   'modifyTime': 1602993274000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '非洲',
#   'provinceId': '10',
#   'provinceName': '埃塞俄比亚',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 65721,
#   'confirmedCount': 87834,
#   'confirmedCountRank': 50,
#   'suspectedCount': 0,
#   'curedCount': 20776,
#   'deadCount': 1337,
#   'deadCountRank': 50,
#   'deadRate': '1.52',
#   'deadRateRank': 124,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 985004,
#   'countryShortCode': 'ETH',
#   'countryFullName': 'Ethiopia',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/406/3402176464316707884-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5841083,
#   'createTime': 1602993273000,
#   'modifyTime': 1602993273000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '亚洲',
#   'provinceId': '10',
#   'provinceName': '印度尼西亚',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 63570,
#   'confirmedCount': 353461,
#   'confirmedCountRank': 19,
#   'suspectedCount': 0,
#   'curedCount': 277544,
#   'deadCount': 12347,
#   'deadCountRank': 17,
#   'deadRate': '3.49',
#   'deadRateRank': 32,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 952005,
#   'countryShortCode': 'IDN',
#   'countryFullName': 'Indonesia',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/308/3402160527840438594-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5840974,
#   'createTime': 1602993273000,
#   'modifyTime': 1602993273000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '欧洲',
#   'provinceId': '10',
#   'provinceName': '德国',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 59037,
#   'confirmedCount': 356387,
#   'confirmedCountRank': 18,
#   'suspectedCount': 0,
#   'curedCount': 287583,
#   'deadCount': 9767,
#   'deadCountRank': 20,
#   'deadRate': '2.74',
#   'deadRateRank': 56,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 963003,
#   'countryShortCode': 'DEU',
#   'countryFullName': 'Germany',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/631/3402160538577680475-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5841227,
#   'createTime': 1602993273000,
#   'modifyTime': 1602993273000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '南美洲',
#   'provinceId': '10',
#   'provinceName': '秘鲁',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 57491,
#   'confirmedCount': 865549,
#   'confirmedCountRank': 8,
#   'suspectedCount': 0,
#   'curedCount': 774356,
#   'deadCount': 33702,
#   'deadCountRank': 8,
#   'deadRate': '3.89',
#   'deadRateRank': 26,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 973008,
#   'countryShortCode': 'PER',
#   'countryFullName': 'Peru',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/005/3402160540725341040-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5841013,
#   'createTime': 1602993273000,
#   'modifyTime': 1602993273000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '亚洲',
#   'provinceId': '10',
#   'provinceName': '伊拉克',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 56199,
#   'confirmedCount': 420303,
#   'confirmedCountRank': 15,
#   'suspectedCount': 0,
#   'curedCount': 353962,
#   'deadCount': 10142,
#   'deadCountRank': 19,
#   'deadRate': '2.41',
#   'deadRateRank': 72,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 955008,
#   'countryShortCode': 'IRQ',
#   'countryFullName': 'Iraq',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/762/3402160510660568794-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5841483,
#   'createTime': 1602993274000,
#   'modifyTime': 1602993274000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '北美洲',
#   'provinceId': '10',
#   'provinceName': '波多黎各',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 55654,
#   'confirmedCount': 56412,
#   'confirmedCountRank': 63,
#   'suspectedCount': 0,
#   'curedCount': 0,
#   'deadCount': 758,
#   'deadCountRank': 69,
#   'deadRate': '1.34',
#   'deadRateRank': 139,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 0,
#   'countryShortCode': 'PRI',
#   'countryFullName': 'Puerto Rico',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0317/609/3402535581564582783-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5841226,
#   'createTime': 1602993273000,
#   'modifyTime': 1602993273000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '非洲',
#   'provinceId': '10',
#   'provinceName': '南非',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 53287,
#   'confirmedCount': 702131,
#   'confirmedCountRank': 12,
#   'suspectedCount': 0,
#   'curedCount': 630436,
#   'deadCount': 18408,
#   'deadCountRank': 14,
#   'deadRate': '2.62',
#   'deadRateRank': 64,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 984011,
#   'countryShortCode': 'ZAF',
#   'countryFullName': 'South Africa',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/417/3402160540725164203-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5840984,
#   'createTime': 1602993273000,
#   'modifyTime': 1602993273000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '亚洲',
#   'provinceId': '10',
#   'provinceName': '菲律宾',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 50354,
#   'confirmedCount': 351750,
#   'confirmedCountRank': 20,
#   'suspectedCount': 0,
#   'curedCount': 294865,
#   'deadCount': 6531,
#   'deadCountRank': 26,
#   'deadRate': '1.85',
#   'deadRateRank': 102,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 952008,
#   'countryShortCode': 'PHL',
#   'countryFullName': 'Philippines',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/180/3402160512807875628-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5841586,
#   'createTime': 1602993274000,
#   'modifyTime': 1602993274000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '非洲',
#   'provinceId': '10',
#   'provinceName': '利比亚',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 45121,
#   'confirmedCount': 47845,
#   'confirmedCountRank': 68,
#   'suspectedCount': 0,
#   'curedCount': 2025,
#   'deadCount': 699,
#   'deadCountRank': 72,
#   'deadRate': '1.46',
#   'deadRateRank': 132,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 981003,
#   'countryShortCode': 'LBY',
#   'countryFullName': 'Libya',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0326/463/3404165384214532747-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5841025,
#   'createTime': 1602993273000,
#   'modifyTime': 1602993273000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '欧洲',
#   'provinceId': '10',
#   'provinceName': '罗马尼亚',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 44053,
#   'confirmedCount': 172516,
#   'confirmedCountRank': 29,
#   'suspectedCount': 0,
#   'curedCount': 122714,
#   'deadCount': 5749,
#   'deadCountRank': 29,
#   'deadRate': '3.33',
#   'deadRateRank': 37,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 965011,
#   'countryShortCode': 'ROU',
#   'countryFullName': 'Romania',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/131/3402160534282712963-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5841361,
#   'createTime': 1602993273000,
#   'modifyTime': 1602993273000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '南美洲',
#   'provinceId': '10',
#   'provinceName': '玻利维亚',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 41880,
#   'confirmedCount': 139319,
#   'confirmedCountRank': 35,
#   'suspectedCount': 0,
#   'curedCount': 89032,
#   'deadCount': 8407,
#   'deadCountRank': 23,
#   'deadRate': '6.03',
#   'deadRateRank': 10,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 973002,
#   'countryShortCode': 'BOL',
#   'countryFullName': 'Bolivia (Plurinational State of)',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/679/3402160529987745516-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5841114,
#   'createTime': 1602993273000,
#   'modifyTime': 1602993273000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '欧洲',
#   'provinceId': '10',
#   'provinceName': '葡萄牙',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 40255,
#   'confirmedCount': 95902,
#   'confirmedCountRank': 46,
#   'suspectedCount': 0,
#   'curedCount': 53498,
#   'deadCount': 2149,
#   'deadCountRank': 40,
#   'deadRate': '2.24',
#   'deadRateRank': 76,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 965010,
#   'countryShortCode': 'PRT',
#   'countryFullName': 'Portugal',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/256/3402160527840261777-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5841282,
#   'createTime': 1602993273000,
#   'modifyTime': 1602993273000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '北美洲',
#   'provinceId': '10',
#   'provinceName': '巴拿马',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 40164,
#   'confirmedCount': 122883,
#   'confirmedCountRank': 38,
#   'suspectedCount': 0,
#   'curedCount': 80190,
#   'deadCount': 2529,
#   'deadCountRank': 38,
#   'deadRate': '2.05',
#   'deadRateRank': 88,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 972007,
#   'countryShortCode': 'PAN',
#   'countryFullName': 'Panama',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/692/3402160525692954763-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5840972,
#   'createTime': 1602993273000,
#   'modifyTime': 1602993273000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '北美洲',
#   'provinceId': '10',
#   'provinceName': '加拿大',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 39699,
#   'confirmedCount': 191732,
#   'confirmedCountRank': 28,
#   'suspectedCount': 0,
#   'curedCount': 142334,
#   'deadCount': 9699,
#   'deadCountRank': 21,
#   'deadRate': '5.05',
#   'deadRateRank': 19,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 971001,
#   'countryShortCode': 'CAN',
#   'countryFullName': 'Canada',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/505/3402160534282712951-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5841231,
#   'createTime': 1602993273000,
#   'modifyTime': 1602993273000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '南美洲',
#   'provinceId': '10',
#   'provinceName': '巴拉圭',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 39137,
#   'confirmedCount': 52596,
#   'confirmedCountRank': 65,
#   'suspectedCount': 0,
#   'curedCount': 12309,
#   'deadCount': 1150,
#   'deadCountRank': 53,
#   'deadRate': '2.18',
#   'deadRateRank': 79,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 973009,
#   'countryShortCode': 'PRY',
#   'countryFullName': 'Paraguay',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/004/3402160529987922312-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5841011,
#   'createTime': 1602993273000,
#   'modifyTime': 1602993273000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '亚洲',
#   'provinceId': '10',
#   'provinceName': '以色列',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 38122,
#   'confirmedCount': 301389,
#   'confirmedCountRank': 24,
#   'suspectedCount': 0,
#   'curedCount': 261128,
#   'deadCount': 2139,
#   'deadCountRank': 41,
#   'deadRate': '0.70',
#   'deadRateRank': 169,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 955009,
#   'countryShortCode': 'ISR',
#   'countryFullName': 'Israel',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/982/3402160514955536220-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5841082,
#   'createTime': 1602993273000,
#   'modifyTime': 1602993273000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '北美洲',
#   'provinceId': '10',
#   'provinceName': '多米尼加',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 37438,
#   'confirmedCount': 120450,
#   'confirmedCountRank': 39,
#   'suspectedCount': 0,
#   'curedCount': 80820,
#   'deadCount': 2192,
#   'deadCountRank': 39,
#   'deadRate': '1.81',
#   'deadRateRank': 104,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 974006,
#   'countryShortCode': 'DOM',
#   'countryFullName': 'Dominican Republic',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/651/3402160506365601251-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5840970,
#   'createTime': 1602993273000,
#   'modifyTime': 1602993273000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '亚洲',
#   'provinceId': '10',
#   'provinceName': '尼泊尔',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 37382,
#   'confirmedCount': 126137,
#   'confirmedCountRank': 37,
#   'suspectedCount': 0,
#   'curedCount': 88040,
#   'deadCount': 715,
#   'deadCountRank': 71,
#   'deadRate': '0.56',
#   'deadRateRank': 178,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 953005,
#   'countryShortCode': 'NPL',
#   'countryFullName': 'Nepal',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/813/3402160536430196712-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5841358,
#   'createTime': 1602993273000,
#   'modifyTime': 1602993273000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '亚洲',
#   'provinceId': '10',
#   'provinceName': '土耳其',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 33704,
#   'confirmedCount': 343955,
#   'confirmedCountRank': 21,
#   'suspectedCount': 0,
#   'curedCount': 301098,
#   'deadCount': 9153,
#   'deadCountRank': 22,
#   'deadRate': '2.66',
#   'deadRateRank': 62,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 955018,
#   'countryShortCode': 'TUR',
#   'countryFullName': 'Turkey',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/952/3402160538577680436-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5841012,
#   'createTime': 1602993273000,
#   'modifyTime': 1602993273000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '亚洲',
#   'provinceId': '10',
#   'provinceName': '黎巴嫩',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 33136,
#   'confirmedCount': 60113,
#   'confirmedCountRank': 61,
#   'suspectedCount': 0,
#   'curedCount': 26468,
#   'deadCount': 509,
#   'deadCountRank': 79,
#   'deadRate': '0.84',
#   'deadRateRank': 161,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 955012,
#   'countryShortCode': 'LBN',
#   'countryFullName': 'Lebanon',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/735/3402160529987745467-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5841576,
#   'createTime': 1602993274000,
#   'modifyTime': 1602993274000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '亚洲',
#   'provinceId': '10',
#   'provinceName': '缅甸',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 31501,
#   'confirmedCount': 33488,
#   'confirmedCountRank': 79,
#   'suspectedCount': 0,
#   'curedCount': 1188,
#   'deadCount': 799,
#   'deadCountRank': 68,
#   'deadRate': '2.38',
#   'deadRateRank': 73,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 952001,
#   'countryShortCode': 'MMR',
#   'countryFullName': 'Myanmar',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0324/456/3403794290450271454-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5841207,
#   'createTime': 1602993273000,
#   'modifyTime': 1602993273000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '欧洲',
#   'provinceId': '10',
#   'provinceName': '匈牙利',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 31079,
#   'confirmedCount': 44816,
#   'confirmedCountRank': 71,
#   'suspectedCount': 0,
#   'curedCount': 12628,
#   'deadCount': 1109,
#   'deadCountRank': 55,
#   'deadRate': '2.47',
#   'deadRateRank': 69,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 963004,
#   'countryShortCode': 'HUN',
#   'countryFullName': 'Hungary',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/954/3402160538577857255-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5841154,
#   'createTime': 1602993273000,
#   'modifyTime': 1602993273000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '非洲',
#   'provinceId': '10',
#   'provinceName': '突尼斯',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 29246,
#   'confirmedCount': 34790,
#   'confirmedCountRank': 76,
#   'suspectedCount': 0,
#   'curedCount': 5032,
#   'deadCount': 512,
#   'deadCountRank': 78,
#   'deadRate': '1.47',
#   'deadRateRank': 130,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 981006,
#   'countryShortCode': 'TUN',
#   'countryFullName': 'Tunisia',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/984/3402160538577857284-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5841014,
#   'createTime': 1602993273000,
#   'modifyTime': 1602993273000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '亚洲',
#   'provinceId': '10',
#   'provinceName': '科威特',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 29059,
#   'confirmedCount': 114744,
#   'confirmedCountRank': 40,
#   'suspectedCount': 0,
#   'curedCount': 84995,
#   'deadCount': 690,
#   'deadCountRank': 73,
#   'deadRate': '0.60',
#   'deadRateRank': 175,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 955011,
#   'countryShortCode': 'KWT',
#   'countryFullName': 'Kuwait',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/529/3402160514955359370-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5841113,
#   'createTime': 1602993273000,
#   'modifyTime': 1602993273000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '亚洲',
#   'provinceId': '10',
#   'provinceName': '约旦',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 27772,
#   'confirmedCount': 34548,
#   'confirmedCountRank': 77,
#   'suspectedCount': 0,
#   'curedCount': 6466,
#   'deadCount': 310,
#   'deadCountRank': 91,
#   'deadRate': '0.89',
#   'deadRateRank': 158,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 955010,
#   'countryShortCode': 'JOR',
#   'countryFullName': 'Jordan',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/225/3402160532135229235-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5841078,
#   'createTime': 1602993273000,
#   'modifyTime': 1602993273000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '南美洲',
#   'provinceId': '10',
#   'provinceName': '厄瓜多尔',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 27006,
#   'confirmedCount': 151659,
#   'confirmedCountRank': 33,
#   'suspectedCount': 0,
#   'curedCount': 112296,
#   'deadCount': 12357,
#   'deadCountRank': 16,
#   'deadRate': '8.14',
#   'deadRateRank': 4,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 973006,
#   'countryShortCode': 'ECU',
#   'countryFullName': 'Ecuador',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/922/3402160517103019900-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5841015,
#   'createTime': 1602993273000,
#   'modifyTime': 1602993273000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '亚洲',
#   'provinceId': '10',
#   'provinceName': '巴林',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 26087,
#   'confirmedCount': 77325,
#   'confirmedCountRank': 54,
#   'suspectedCount': 0,
#   'curedCount': 50946,
#   'deadCount': 292,
#   'deadCountRank': 93,
#   'deadRate': '0.37',
#   'deadRateRank': 182,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 955004,
#   'countryShortCode': 'BHR',
#   'countryFullName': 'Bahrain',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/852/3402160536430196734-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5841527,
#   'createTime': 1602993274000,
#   'modifyTime': 1602993274000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '北美洲',
#   'provinceId': '10',
#   'provinceName': '萨尔瓦多',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 26085,
#   'confirmedCount': 31265,
#   'confirmedCountRank': 81,
#   'suspectedCount': 0,
#   'curedCount': 4268,
#   'deadCount': 912,
#   'deadCountRank': 62,
#   'deadRate': '2.91',
#   'deadRateRank': 52,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 972003,
#   'countryShortCode': 'SLV',
#   'countryFullName': 'The Republic of El Salvador',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0320/757/3403052105068803877-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5841112,
#   'createTime': 1602993273000,
#   'modifyTime': 1602993273000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '非洲',
#   'provinceId': '10',
#   'provinceName': '摩洛哥',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 25341,
#   'confirmedCount': 167148,
#   'confirmedCountRank': 30,
#   'suspectedCount': 0,
#   'curedCount': 138989,
#   'deadCount': 2818,
#   'deadCountRank': 36,
#   'deadRate': '1.68',
#   'deadRateRank': 115,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 981004,
#   'countryShortCode': 'MAR',
#   'countryFullName': 'Morocco',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/520/3402160510660391844-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5841019,
#   'createTime': 1602993273000,
#   'modifyTime': 1602993273000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '欧洲',
#   'provinceId': '10',
#   'provinceName': '瑞士',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 24405,
#   'confirmedCount': 74227,
#   'confirmedCountRank': 55,
#   'suspectedCount': 0,
#   'curedCount': 48000,
#   'deadCount': 1822,
#   'deadCountRank': 45,
#   'deadRate': '2.45',
#   'deadRateRank': 70,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 963008,
#   'countryShortCode': 'CHE',
#   'countryFullName': 'Switzerland',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/786/3402160525692954837-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5841021,
#   'createTime': 1602993273000,
#   'modifyTime': 1602993273000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '欧洲',
#   'provinceId': '10',
#   'provinceName': '奥地利',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 24368,
#   'confirmedCount': 62455,
#   'confirmedCountRank': 59,
#   'suspectedCount': 0,
#   'curedCount': 37186,
#   'deadCount': 901,
#   'deadCountRank': 64,
#   'deadRate': '1.44',
#   'deadRateRank': 135,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 963001,
#   'countryShortCode': 'AUT',
#   'countryFullName': 'Austria',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/012/3402160532135229192-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5841237,
#   'createTime': 1602993273000,
#   'modifyTime': 1602993273000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '欧洲',
#   'provinceId': '10',
#   'provinceName': '摩尔多瓦',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 24309,
#   'confirmedCount': 65860,
#   'confirmedCountRank': 56,
#   'suspectedCount': 0,
#   'curedCount': 40002,
#   'deadCount': 1549,
#   'deadCountRank': 47,
#   'deadRate': '2.35',
#   'deadRateRank': 74,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 964005,
#   'countryShortCode': 'MDA',
#   'countryFullName': 'Republic of Moldova',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/234/3402160527840438516-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5841022,
#   'createTime': 1602993273000,
#   'modifyTime': 1602993273000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '欧洲',
#   'provinceId': '10',
#   'provinceName': '希腊',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 22487,
#   'confirmedCount': 24450,
#   'confirmedCountRank': 86,
#   'suspectedCount': 0,
#   'curedCount': 1473,
#   'deadCount': 490,
#   'deadCountRank': 80,
#   'deadRate': '2.00',
#   'deadRateRank': 92,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 965007,
#   'countryShortCode': 'GRC',
#   'countryFullName': 'Greece',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/800/3402160534282889817-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5841076,
#   'createTime': 1602993273000,
#   'modifyTime': 1602993273000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '欧洲',
#   'provinceId': '10',
#   'provinceName': '爱尔兰',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 22237,
#   'confirmedCount': 47427,
#   'confirmedCountRank': 69,
#   'suspectedCount': 0,
#   'curedCount': 23349,
#   'deadCount': 1841,
#   'deadCountRank': 43,
#   'deadRate': '3.88',
#   'deadRateRank': 27,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 961003,
#   'countryShortCode': 'IRL',
#   'countryFullName': 'Ireland',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/153/3402160510660568721-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5841080,
#   'createTime': 1602993273000,
#   'modifyTime': 1602993273000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '亚洲',
#   'provinceId': '10',
#   'provinceName': '亚美尼亚',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 22110,
#   'confirmedCount': 63000,
#   'confirmedCountRank': 57,
#   'suspectedCount': 0,
#   'curedCount': 39823,
#   'deadCount': 1067,
#   'deadCountRank': 58,
#   'deadRate': '1.69',
#   'deadRateRank': 114,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 955002,
#   'countryShortCode': 'ARM',
#   'countryFullName': 'Armenia',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/583/3402160508513085016-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5841452,
#   'createTime': 1602993274000,
#   'modifyTime': 1602993274000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '非洲',
#   'provinceId': '10',
#   'provinceName': '肯尼亚',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 21609,
#   'confirmedCount': 43580,
#   'confirmedCountRank': 73,
#   'suspectedCount': 0,
#   'curedCount': 21158,
#   'deadCount': 813,
#   'deadCountRank': 67,
#   'deadRate': '1.86',
#   'deadRateRank': 101,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 985005,
#   'countryShortCode': 'KEN',
#   'countryFullName': 'Kenya',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0317/555/3402535553647091609-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5841482,
#   'createTime': 1602993274000,
#   'modifyTime': 1602993274000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '亚洲',
#   'provinceId': '10',
#   'provinceName': '乌兹别克斯坦',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 20125,
#   'confirmedCount': 62809,
#   'confirmedCountRank': 58,
#   'suspectedCount': 0,
#   'curedCount': 42162,
#   'deadCount': 522,
#   'deadCountRank': 77,
#   'deadRate': '0.83',
#   'deadRateRank': 163,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 954005,
# ...
#   'currentConfirmedCount': 109,
#   'confirmedCount': 112,
#   'confirmedCountRank': 197,
#   'suspectedCount': 0,
#   'curedCount': 0,
#   'deadCount': 3,
#   'deadCountRank': 185,
#   'deadRate': '2.67',
#   'deadRateRank': 60,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 974001,
#   'countryShortCode': 'ATG',
#   'countryFullName': 'Antigua & Barbuda',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/128/3402176462169224100-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5841607,
#   'createTime': 1602993274000,
#   'modifyTime': 1602993274000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '大洋洲',
#   'provinceId': '10',
#   'provinceName': '北马里亚纳群岛联邦',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 78,
#   'confirmedCount': 80,
#   'suspectedCount': 0,
#   'curedCount': 0,
#   'deadCount': 2,
#   'deadRate': '2.50',
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 0,
#   'countryShortCode': 'CNMI',
#   'countryFullName': 'Northern Mariana Islands (Commonwealth of the)',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0330/319/3404907558858335978-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': False},
#  {'id': 5841143,
#   'createTime': 1602993273000,
#   'modifyTime': 1602993273000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '欧洲',
#   'provinceId': '10',
#   'provinceName': '列支敦士登',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 77,
#   'confirmedCount': 195,
#   'confirmedCountRank': 193,
#   'suspectedCount': 0,
#   'curedCount': 117,
#   'deadCount': 1,
#   'deadCountRank': 190,
#   'deadRate': '0.51',
#   'deadRateRank': 179,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 963005,
#   'countryShortCode': 'LIE',
#   'countryFullName': 'Liechtenstein',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/312/3402160514955359362-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5841525,
#   'createTime': 1602993274000,
#   'modifyTime': 1602993274000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '非洲',
#   'provinceId': '10',
#   'provinceName': '毛里求斯',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 72,
#   'confirmedCount': 407,
#   'confirmedCountRank': 184,
#   'suspectedCount': 0,
#   'curedCount': 325,
#   'deadCount': 10,
#   'deadCountRank': 178,
#   'deadRate': '2.45',
#   'deadRateRank': 70,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 984014,
#   'countryShortCode': 'MUS',
#   'countryFullName': 'Mauritius',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0320/751/3403052105069099803-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True},
#  {'id': 5841493,
#   'createTime': 1602993274000,
#   'modifyTime': 1602993274000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '北美洲',
#   'provinceId': '10',
#   'provinceName': '圣巴泰勒米岛',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 72,
#   'confirmedCount': 72,
#   'suspectedCount': 0,
#   'curedCount': 0,
#   'deadCount': 0,
#   'deadRate': '0.00',
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 0,
#   'countryShortCode': 'BL',
#   'countryFullName': 'Saint Barthelemy',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0317/743/3402535562237228754-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': False},
#  {'id': 5841604,
#   'createTime': 1602993274000,
#   'modifyTime': 1602993274000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '北美洲',
#   'provinceId': '10',
#   'provinceName': '英属维尔京群岛',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 71,
#   'confirmedCount': 72,
#   'suspectedCount': 0,
#   'curedCount': 0,
#   'deadCount': 1,
#   'deadRate': '1.38',
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 0,
#   'countryShortCode': 'VG',
#   'countryFullName': 'VirginIslands,British',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0328/125/3404536465093935059-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': False},
#  {'id': 5841467,
#   'createTime': 1602993274000,
#   'modifyTime': 1602993274000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '北美洲',
#   'provinceId': '10',
#   'provinceName': '圣文森特和格林纳丁斯',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 65,
#   'confirmedCount': 65,
#   'suspectedCount': 0,
#   'curedCount': 0,
#   'deadCount': 0,
#   'deadRate': '0.00',
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 974012,
#   'countryShortCode': 'VCT',
#   'countryFullName': 'Saint Vincent and the Grenadines',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/434/3402160510660391899-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': False},
#  {'id': 5841582,
#   'createTime': 1602993274000,
#   'modifyTime': 1602993274000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '北美洲',
#   'provinceId': '10',
#   'provinceName': '多米尼克',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 33,
#   'confirmedCount': 33,
#   'suspectedCount': 0,
#   'curedCount': 0,
#   'deadCount': 0,
#   'deadRate': '0.00',
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 974005,
#   'countryShortCode': 'DMA',
#   'countryFullName': 'Dominica',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0325/162/3403979839479547471-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': False},
#  {'id': 5841492,
#   'createTime': 1602993274000,
#   'modifyTime': 1602993274000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '北美洲',
#   'provinceId': '10',
#   'provinceName': '圣卢西亚',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 32,
#   'confirmedCount': 32,
#   'suspectedCount': 0,
#   'curedCount': 0,
#   'deadCount': 0,
#   'deadRate': '0.00',
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 974011,
#   'countryShortCode': 'LCA',
#   'countryFullName': 'Saint Lucia',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0317/755/3402535592301799597-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': False},
#  {'id': 5841530,
#   'createTime': 1602993274000,
#   'modifyTime': 1602993274000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '大洋洲',
#   'provinceId': '10',
#   'provinceName': '斐济',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 30,
#   'confirmedCount': 32,
#   'suspectedCount': 0,
#   'curedCount': 0,
#   'deadCount': 2,
#   'deadRate': '6.25',
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 990002,
#   'countryShortCode': 'FJI',
#   'countryFullName': 'The Republic of Fiji',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0320/440/3403052105069099849-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': False},
#  {'id': 5841561,
#   'createTime': 1602993274000,
#   'modifyTime': 1602993274000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '亚洲',
#   'provinceId': '10',
#   'provinceName': '东帝汶',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 29,
#   'confirmedCount': 29,
#   'suspectedCount': 0,
#   'curedCount': 0,
#   'deadCount': 0,
#   'deadRate': '0.00',
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 952004,
#   'countryShortCode': 'TLS',
#   'countryFullName': 'Tinor-Leste',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0322/192/3403423200980673679-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': False},
#  {'id': 5841559,
#   'createTime': 1602993274000,
#   'modifyTime': 1602993274000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '大洋洲',
#   'provinceId': '10',
#   'provinceName': '新喀里多尼亚',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 27,
#   'confirmedCount': 27,
#   'suspectedCount': 0,
#   'curedCount': 0,
#   'deadCount': 0,
#   'deadRate': '0.00',
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 0,
#   'countryShortCode': 'NCL',
#   'countryFullName': 'New Caledonia',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0321/445/3403237656246202288-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': False},
#  {'id': 5841223,
#   'createTime': 1602993273000,
#   'modifyTime': 1602993273000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '欧洲',
#   'provinceId': '10',
#   'provinceName': '梵蒂冈',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 26,
#   'confirmedCount': 26,
#   'suspectedCount': 0,
#   'curedCount': 0,
#   'deadCount': 0,
#   'deadRate': '0.00',
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 965017,
#   'countryShortCode': 'VAT',
#   'countryFullName': 'Holy See',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/719/3402160489185554691-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': False},
#  {'id': 5841578,
#   'createTime': 1602993274000,
#   'modifyTime': 1602993274000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '北美洲',
#   'provinceId': '10',
#   'provinceName': '格林那达',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 25,
#   'confirmedCount': 25,
#   'suspectedCount': 0,
#   'curedCount': 0,
#   'deadCount': 0,
#   'deadRate': '0.00',
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 0,
#   'countryShortCode': 'GRD',
#   'countryFullName': 'Grenada',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0324/601/3403794292597755143-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': False},
#  {'id': 5841580,
#   'createTime': 1602993274000,
#   'modifyTime': 1602993274000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '亚洲',
#   'provinceId': '10',
#   'provinceName': '老挝',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 23,
#   'confirmedCount': 23,
#   'suspectedCount': 0,
#   'curedCount': 0,
#   'deadCount': 0,
#   'deadRate': '0.00',
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 952006,
#   'countryShortCode': 'LAO',
#   'countryFullName': 'Laos',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0325/227/3403979839479981624-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': False},
#  {'id': 5841587,
#   'createTime': 1602993274000,
#   'modifyTime': 1602993274000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '北美洲',
#   'provinceId': '10',
#   'provinceName': '圣其茨和尼维斯',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 19,
#   'confirmedCount': 19,
#   'suspectedCount': 0,
#   'curedCount': 0,
#   'deadCount': 0,
#   'deadRate': '0.00',
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 0,
#   'countryShortCode': 'KNA',
#   'countryFullName': 'Saint Kitts and Nevis',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0327/418/3404350922506635659-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': False},
#  {'id': 5841488,
#   'createTime': 1602993274000,
#   'modifyTime': 1602993274000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '北美洲',
#   'provinceId': '10',
#   'provinceName': '格陵兰',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 16,
#   'confirmedCount': 16,
#   'suspectedCount': 0,
#   'curedCount': 0,
#   'deadCount': 0,
#   'deadRate': '0.00',
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 0,
#   'countryShortCode': 'GRL',
#   'countryFullName': 'Greenland',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0320/865/3403052100773836376-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': False},
#  {'id': 5841619,
#   'createTime': 1602993274000,
#   'modifyTime': 1602993274000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '北美洲',
#   'provinceId': '10',
#   'provinceName': '圣皮埃尔和密克隆群岛',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 16,
#   'confirmedCount': 16,
#   'suspectedCount': 0,
#   'curedCount': 0,
#   'deadCount': 0,
#   'deadRate': '0.00',
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 0,
#   'countryShortCode': 'SPM',
#   'countryFullName': 'Saint Pierre and Miquelon',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0409/335/3406762986877325512-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': False},
#  {'id': 5841616,
#   'createTime': 1602993274000,
#   'modifyTime': 1602993274000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '南美洲',
#   'provinceId': '10',
#   'provinceName': '福克兰群岛',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 13,
#   'confirmedCount': 13,
#   'suspectedCount': 0,
#   'curedCount': 0,
#   'deadCount': 0,
#   'deadRate': '0.00',
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 0,
#   'countryShortCode': 'FLK',
#   'countryFullName': 'Falkland Islands',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0406/989/3406206348378627968-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': False},
#  {'id': 5841570,
#   'createTime': 1602993274000,
#   'modifyTime': 1602993274000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '北美洲',
#   'provinceId': '10',
#   'provinceName': '蒙特塞拉特',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 12,
#   'confirmedCount': 13,
#   'suspectedCount': 0,
#   'curedCount': 0,
#   'deadCount': 1,
#   'deadRate': '7.69',
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 0,
#   'countryShortCode': 'MS',
#   'countryFullName': 'Montserrat',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0323/017/3403608739273213039-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': False},
#  {'id': 5841603,
#   'createTime': 1602993274000,
#   'modifyTime': 1602993274000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '北美洲',
#   'provinceId': '10',
#   'provinceName': '安圭拉',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 3,
#   'confirmedCount': 3,
#   'suspectedCount': 0,
#   'curedCount': 0,
#   'deadCount': 0,
#   'deadRate': '0.00',
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 0,
#   'countryShortCode': 'AI',
#   'countryFullName': 'Anguilla',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0328/700/3404536465093591382-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': False},
#  {'id': 5841284,
#   'createTime': 1602993273000,
#   'modifyTime': 1602993273000,
#   'tags': '',
#   'countryType': 2,
#   'continents': '亚洲',
#   'provinceId': '10',
#   'provinceName': '文莱',
#   'provinceShortName': '',
#   'cityName': '',
#   'currentConfirmedCount': 1,
#   'confirmedCount': 147,
#   'confirmedCountRank': 196,
#   'suspectedCount': 0,
#   'curedCount': 143,
#   'deadCount': 3,
#   'deadCountRank': 185,
#   'deadRate': '2.04',
#   'deadRateRank': 90,
#   'comment': '',
#   'sort': 0,
#   'operator': 'weiw',
#   'locationId': 952002,
#   'countryShortCode': 'BRN',
#   'countryFullName': 'Brunei Darussalam',
#   'statisticsData': 'https://file1.dxycdn.com/2020/0315/199/3402160540725164222-135.json',
#   'incrVo': {'currentConfirmedIncr': 0,
#    'confirmedIncr': 0,
#    'curedIncr': 0,
#    'deadIncr': 0},
#   'showRank': True})

# %%
country = []
confirmed = []
lived =[]
dead =[]

# %%
# 分离国家名称，确诊人数、治愈人书和死亡人数并存入dataframe
for i in ncov_world:
    country.append(i['provinceName'])
    confirmed.append(i['confirmedCount'])
    lived.append(i['curedCount'])
    dead.append(i['deadCount'])
    
data_world = pd.DataFrame()
data_world['国家名称'] = country
data_world['确诊人数'] = confirmed
data_world['治愈人数'] = lived
data_world['死亡人数'] = dead
data_world.head()
# Out:
#   国家名称     确诊人数     治愈人数    死亡人数
# 0   美国  8102142  3220573  219285
# 1   印度  7432680  6524595  112998
# 2  西班牙   936560   150376   33775
# 3   法国   834770   104696   33303
# 4   英国   705428      539   43579

# %%
data_world
# Out:
#            国家名称     确诊人数     治愈人数    死亡人数
# 0            美国  8102142  3220573  219285
# 1            印度  7432680  6524595  112998
# 2           西班牙   936560   150376   33775
# 3            法国   834770   104696   33303
# 4            英国   705428      539   43579
# 5            巴西  5224362  4635315  153690
# 6           俄罗斯  1384235  1065199   24002
# 7            荷兰   211690    11886    6699
# 8           比利时   202058    19239   10359
# 9           乌克兰   293641   121919    5517
# 10          阿根廷   979106   791161   26107
# 11          墨西哥   841661   612216   85704
# 12          意大利   391611   247872   36427
# 13           捷克   160112    63350    1283
# 14         危地马拉   100431     3123    3478
# 15           瑞典   103200     4971    5918
# 16        哥斯达黎加    93152     1280    1159
# 17         委内瑞拉    85469     1649     720
# 18         洪都拉斯    86089     1767    2552
# 19         孟加拉国   387295   302298    5646
# 20         哥伦比亚   952371   847467   28803
# 21           伊朗   526490   423921   30123
# 22           波兰   157608    85588    3440
# 23        埃塞俄比亚    87834    20776    1337
# 24        印度尼西亚   353461   277544   12347
# 25           德国   356387   287583    9767
# 26           秘鲁   865549   774356   33702
# 27          伊拉克   420303   353962   10142
# 28         波多黎各    56412        0     758
# 29           南非   702131   630436   18408
# ..          ...      ...      ...     ...
# 185         摩纳哥      255        3       3
# 186         根西岛      258        0      13
# 187        开曼群岛      225        0       2
# 188        巴巴多斯      218        0       7
# 189         百慕大      185        0       9
# 190         柬埔寨      283      122       0
# 191     钻石公主号邮轮      741      574      13
# 192     荷兰加勒比地区      150        0       3
# 193     安提瓜和巴布达      112        0       3
# 194   北马里亚纳群岛联邦       80        0       2
# 195       列支敦士登      195      117       1
# 196        毛里求斯      407      325      10
# 197      圣巴泰勒米岛       72        0       0
# 198     英属维尔京群岛       72        0       1
# 199  圣文森特和格林纳丁斯       65        0       0
# 200        多米尼克       33        0       0
# 201        圣卢西亚       32        0       0
# 202          斐济       32        0       2
# 203         东帝汶       29        0       0
# 204      新喀里多尼亚       27        0       0
# 205         梵蒂冈       26        0       0
# 206        格林那达       25        0       0
# 207          老挝       23        0       0
# 208     圣其茨和尼维斯       19        0       0
# 209         格陵兰       16        0       0
# 210  圣皮埃尔和密克隆群岛       16        0       0
# 211       福克兰群岛       13        0       0
# 212       蒙特塞拉特       13        0       1
# 213         安圭拉        3        0       0
# 214          文莱      147      143       3
#
# [215 rows x 4 columns]

# %% [markdown]
# ### GDP数据分分析

# %% [markdown]
# - pandas.date_range()详解
#
# | 参数 | 数据类型 | 意义 |
# | ---- | ---- | ---- |
# |start	|str or datetime-like, optional	|生成日期的左侧边界|
# |end	|str or datetime-like, optional	|生成日期的右侧边界|
# |periods	|integer, optional	|生成周期|
# |freq	|str or DateOffset, default ‘D’	|可以有多种比如‘5H’，频率别名参见链接|
# |tz	|str or tzinfo, optional	|返回本地化的DatetimeIndex的时区名，例如’Asia/Hong_Kong’|
# |normalize	|bool, default False	|生成日期之前，将开始/结束时间初始化为午夜|
# |name	|str, default None	|产生的DatetimeIndex的名字|
# |closed	|{None, ‘left’, ‘right’}, optional	|使区间相对于给定频率左闭合、右闭合、双向闭合（默认的None）|
# |**kwargs	| 	 为了兼容性，对结果没有影响 |

# %%
data_economy = pd.read_csv("./dataset/gpd_2016_2020.csv",index_col=0)
time_index = pd.date_range(start='2016',periods=18,freq='Q')
data_economy.index = time_index
data_economy
# Out:
#               国内生产总值  第一产业增加值   第二产业增加值   第三产业增加值  农林牧渔业增加值    工业增加值   制造业增加值  \
# 2016-03-31  162410.0   8312.7   61106.8   92990.5    8665.5  53666.4  45784.0
# 2016-06-30  181408.2  12555.9   73416.5   95435.8   13045.5  60839.2  52378.3
# 2016-09-30  191010.6  17542.4   75400.5   98067.8   18162.2  61902.5  52468.3
# 2016-12-31  211566.2  21728.2   85504.1  104334.0   22577.8  68998.4  58878.4
# 2017-03-31  181867.7   8205.9   69315.5  104346.3    8595.8  60909.3  51419.7
# 2017-06-30  201950.3  12644.9   82323.0  106982.4   13204.2  68099.8  58172.1
# 2017-09-30  212789.3  18255.8   84574.1  109959.5   18944.2  69327.2  58632.6
# 2017-12-31  235428.7  22992.9   95368.0  117067.8   23915.8  76782.9  65652.1
# 2018-03-31  202035.7   8575.7   76598.2  116861.8    9005.8  66905.6  56631.9
# 2018-06-30  223962.2  13003.8   91100.6  119857.8   13662.2  75122.1  64294.9
# 2018-09-30  234474.3  18226.9   93112.5  123134.9   18961.8  76239.6  64348.2
# 2018-12-31  258808.9  24938.7  104023.9  129846.2   25929.0  82822.1  70662.1
# 2019-03-31  218062.8   8769.4   81806.5  127486.9    9249.4  71064.5  60357.1
# 2019-06-30  242573.8  14437.6   97315.6  130820.6   15108.7  79820.7  68041.8
# 2019-09-30  252208.7  19798.0   97790.4  134620.4   20629.0  79501.8  66823.8
# 2019-12-31  278019.7  27461.6  109252.8  141305.2   28579.9  86721.6  73952.4
# 2020-03-31  206504.3  10186.2   73638.0  122680.1   10708.4  64642.0  53852.0
# 2020-06-30  250110.1  15866.8   99120.9  135122.3   16596.4  80402.4  69258.8
#
#              建筑业增加值  批发和零售业增加值  交通运输、仓储和邮政业增加值  住宿和餐饮业增加值   金融业增加值  房地产业增加值  \
# 2016-03-31   7763.0    16847.5          7180.5     3181.6  15340.4  11283.0
# 2016-06-30  12943.8    17679.8          8295.0     3112.3  14811.7  12209.7
# 2016-09-30  13870.6    18513.0          8591.6     3473.2  14945.4  12615.3
# 2016-12-31  16921.5    20684.1          8961.6     3840.7  14866.4  13861.4
# 2017-03-31   8725.3    18608.9          8094.5     3536.5  16758.8  13047.0
# 2017-06-30  14574.4    19473.6          9397.7     3440.9  15856.3  14059.0
# 2017-09-30  15590.1    20342.9          9688.7     3838.5  16290.4  14054.9
# 2017-12-31  19015.8    22731.1          9940.9     4240.1  15938.8  15925.1
# 2018-03-31  10073.8    20485.5          8806.5     3887.8  18050.6  14863.5
# 2018-06-30  16404.3    21374.2         10174.9     3779.6  17401.0  16176.1
# 2018-09-30  17294.5    22334.1         10582.3     4212.6  17780.6  15914.0
# 2018-12-31  21720.4    24710.0         10773.5     4640.6  17378.1  17669.5
# 2019-03-31  11143.1    21959.2          9386.6     4234.9  19650.1  15979.2
# 2019-06-30  17954.2    23097.0         10861.3     4123.0  19064.9  17484.4
# 2019-09-30  18734.6    23993.6         11310.2     4610.5  19388.3  17369.0
# 2019-12-31  23072.4    26795.9         11244.0     5071.2  18973.8  18798.9
# 2020-03-31   9377.8    18749.6          7865.1     2820.9  21346.8  15268.3
# 2020-06-30  19156.8    23696.1         10650.0     3481.3  20954.7  18593.6
#
#             信息传输、软件和信息技术服务业增加值  租赁和商务服务业增加值  其他行业增加值
# 2016-03-31              5128.8       4985.3  28368.1
# 2016-06-30              5130.7       5075.1  28265.4
# 2016-09-30              4662.3       5452.4  28822.1
# 2016-12-31              5202.3       6015.8  29636.1
# 2017-03-31              5915.2       5811.9  31864.3
# 2017-06-30              5977.9       5868.4  31998.1
# 2017-09-30              5539.8       6464.6  32708.0
# 2017-12-31              6376.0       7128.4  33433.7
# 2018-03-31              7212.2       6879.5  35864.9
# 2018-06-30              7309.6       6885.3  35673.1
# 2018-09-30              6690.9       7533.3  36930.6
# 2018-12-31              7520.8       8170.4  37474.6
# 2019-03-31              8424.8       7665.1  39306.0
# 2019-06-30              8395.6       7596.7  39067.3
# 2019-09-30              7528.1       8409.1  40734.5
# 2019-12-31              8341.3       9262.5  41158.2
# 2020-03-31              8928.0       7137.9  39659.6
# 2020-06-30              9573.0       7174.4  39831.4

# %%
data_area = pd.read_csv('https://labfile.oss.aliyuncs.com/courses/2791/DXYArea.csv')
data_area.head()
data_news = pd.read_csv('https://labfile.oss.aliyuncs.com/courses/2791/DXYNews.csv')
data_news.head()
# Out:
#                         _id     id              pubDate  \
# 0  5f10e2359a94f2b3c3837ccf  65725  2020-07-17 05:40:08
# 1  5f10e1409a94f2b3c3837cce  65728  2020-07-17 06:06:49
# 2  5f1070fd9a94f2b3c3837c7a  65679  2020-07-16 22:31:00
# 3  5f1070fd9a94f2b3c3837c7b  65681  2020-07-16 22:29:48
# 4  5f1058ae9a94f2b3c3837c79  65663  2020-07-16 21:26:54
#
#                             title  \
# 0   美国新增71434例新冠肺炎确诊病例，累计确诊超354万例
# 1  巴西新冠肺炎确诊病例破201万，近六成大城市确诊病例加速增长
# 2   阿塞拜疆新增493例新冠肺炎确诊病例 累计确诊26165例
# 3   ​科威特新增791例新冠肺炎确诊病例 累计确诊57668例
# 4   罗马尼亚新增777例新冠肺炎确诊病例 累计确诊35003例
#
#                                              summary infoSource  \
# 0  据美国约翰斯·霍普金斯大学统计数据显示，截至美东时间7月16日17:33时（北京时间17日0...    央视新闻app
# 1  截至当地时间7月16日18时，巴西新增新冠肺炎确诊病例45403例，累计确诊2012151例...    央视新闻app
# 2  当地时间7月16日，阿塞拜疆国家疫情防控指挥部发布消息，在过去24小时内，阿塞拜疆新增新冠肺...    央视新闻app
# 3  科威特卫生部当地时间16日下午发布通告，确认过去24小时境内新增791例新冠肺炎确诊病例，同...    央视新闻app
# 4  据罗马尼亚政府7月16日公布的数据，过去24小时对19097人进行新冠病毒检测，确诊777例...    央视新闻app
#
#                                            sourceUrl  provinceId  \
# 0  http://app.cctv.com/special/cportal/detail/art...         NaN
# 1  http://app.cctv.com/special/cportal/detail/art...         NaN
# 2  http://app.cctv.com/special/cportal/detail/art...         NaN
# 3  http://app.cctv.com/special/cportal/detail/art...         NaN
# 4  http://app.cctv.com/special/cportal/detail/art...         NaN
#
#              crawlTime  entryWay  infoType  dataInfoState dataInfoOperator  \
# 0  2020-07-17 07:26:44       NaN       NaN            NaN              NaN
# 1  2020-07-17 07:22:39       NaN       NaN            NaN              NaN
# 2  2020-07-16 23:23:39       NaN       NaN            NaN              NaN
# 3  2020-07-16 23:23:39       NaN       NaN            NaN              NaN
# 4  2020-07-16 21:39:57       NaN       NaN            NaN              NaN
#
#   dataInfoTime provinceName createTime modifyTime  adoptType body
# 0          NaN          NaN        NaN        NaN        NaN  NaN
# 1          NaN          NaN        NaN        NaN        NaN  NaN
# 2          NaN          NaN        NaN        NaN        NaN  NaN
# 3          NaN          NaN        NaN        NaN        NaN  NaN
# 4          NaN          NaN        NaN        NaN        NaN  NaN

# %% [markdown]
# ## 数据预处理

# %%
data_area = data_area[data_area['countryName'] == data_area['provinceName']]
data_area_times = data_area[['countryName','province_confirmedCount',
                             'province_curedCount','province_deadCount','updateTime']]

# 根据疫情更新时间来生成时间序列
time = pd.DatetimeIndex(data_area_times['updateTime'])
# 生成索引
data_area_times.index = time
data_area_times = data_area_times.drop('updateTime',axis=1)
data_area_times.head()

# 查询是否有空值
data_area_times.isnull().sum()
data_area_times.isnull().any()
# Out:
# countryName                False
# province_confirmedCount    False
# province_curedCount        False
# province_deadCount         False
# dtype: bool

# %%
data_news_times = data_news[['pubDate','title','summary']]
time = pd.DatetimeIndex(data_news_times['pubDate'])
data_news_times.index = time
data_news_times = data_news_times.drop('pubDate',axis = 1)
data_news_times.head()
# Out:
#                                               title  \
# pubDate
# 2020-07-17 05:40:08   美国新增71434例新冠肺炎确诊病例，累计确诊超354万例
# 2020-07-17 06:06:49  巴西新冠肺炎确诊病例破201万，近六成大城市确诊病例加速增长
# 2020-07-16 22:31:00   阿塞拜疆新增493例新冠肺炎确诊病例 累计确诊26165例
# 2020-07-16 22:29:48   ​科威特新增791例新冠肺炎确诊病例 累计确诊57668例
# 2020-07-16 21:26:54   罗马尼亚新增777例新冠肺炎确诊病例 累计确诊35003例
#
#                                                                summary
# pubDate
# 2020-07-17 05:40:08  据美国约翰斯·霍普金斯大学统计数据显示，截至美东时间7月16日17:33时（北京时间17日0...
# 2020-07-17 06:06:49  截至当地时间7月16日18时，巴西新增新冠肺炎确诊病例45403例，累计确诊2012151例...
# 2020-07-16 22:31:00  当地时间7月16日，阿塞拜疆国家疫情防控指挥部发布消息，在过去24小时内，阿塞拜疆新增新冠肺...
# 2020-07-16 22:29:48  科威特卫生部当地时间16日下午发布通告，确认过去24小时境内新增791例新冠肺炎确诊病例，同...
# 2020-07-16 21:26:54  据罗马尼亚政府7月16日公布的数据，过去24小时对19097人进行新冠病毒检测，确诊777例...

# %%
print(data_economy.isnull().sum())
print(data_world.isnull().sum())
print(data_area_times.isnull().sum())
print(data_news_times.isnull().sum())
# Out:
# 国内生产总值                0
# 第一产业增加值               0
# 第二产业增加值               0
# 第三产业增加值               0
# 农林牧渔业增加值              0
# 工业增加值                 0
# 制造业增加值                0
# 建筑业增加值                0
# 批发和零售业增加值             0
# 交通运输、仓储和邮政业增加值        0
# 住宿和餐饮业增加值             0
# 金融业增加值                0
# 房地产业增加值               0
# 信息传输、软件和信息技术服务业增加值    0
# 租赁和商务服务业增加值           0
# 其他行业增加值               0
# dtype: int64
# 国家名称    0
# 确诊人数    0
# 治愈人数    0
# 死亡人数    0
# dtype: int64
# countryName                0
# province_confirmedCount    0
# province_curedCount        0
# province_deadCount         0
# dtype: int64
# title      0
# summary    0
# dtype: int64

# %% [markdown]
# ### 疫情现状数据分析

# %%
# 下载开源字体思源黑体
# !wget -nc "https://labfile.oss.aliyuncs.com/courses/2791/NotoSansCJK.otf"
# Out:
# 'wget' 不是内部或外部命令，也不是可运行的程序
# 或批处理文件。

# %%
import matplotlib.pyplot as plt
import matplotlib
import os
# %matplotlib inline

# %% [markdown]
# ##### sort_values()
# - by	指定列名(axis=0或’index’)或索引值(axis=1或’columns’)
# - axis	若axis=0或’index’，则按照指定列中数据大小排序；若axis=1或’columns’，则按照指定索引中数据大小排序，默认axis=0
# - ascending	是否按指定列的数组升序排列，默认为True，即升序排列
# - inplace	是否用排序后的数据集替换原来的数据，默认为False，即不替换
# - na_position	{‘first’,‘last’}，设定缺失值的显示位置

# %%
# 设置字体
font_path = "./NotoSansCJK.otf"
myfont = matplotlib.font_manager.FontProperties(fname=font_path)

# 绘图
# 
data_world = data_world.sort_values(by='确诊人数' ,ascending=False)
